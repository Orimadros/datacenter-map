# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import time
from geopy.geocoders import Nominatim

# %% [markdown]
# ## 1. Loading data + manipulation

# %%
# Define the path to the raw data file
raw_datacenters_path = Path.cwd().parent / 'data' / 'raw' / 'datacenter_map_scraped.csv'

# Load the raw data into a DataFrame
raw_datacenters = pd.read_csv(raw_datacenters_path)

# Drop the unnamed column
raw_datacenters = raw_datacenters.drop(columns='Unnamed: 0')

# Extract the provider name from the 'name' column using regex
provider_regex = r'(.*):'
raw_datacenters['provider'] = raw_datacenters['name'].str.extract(provider_regex)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 raw_datacenters_path = Path.cwd().parent / 'data' / 'raw' / 'datacenter_map_scraped_brasil.csv'
#       4 # Load the raw data into a DataFrame
# ----> 5 raw_datacenters = pd.read_csv(raw_datacenters_path)
#       7 # Drop the unnamed column
#       8 raw_datacenters = raw_datacenters.drop(columns='Unnamed: 0')
#
# File ~/myproject/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/myproject/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/myproject/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/myproject/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/myproject/venv/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/leonardogomes/Library/CloudStorage/GoogleDrive-leodavinci550@gmail.com/My Drive/Elementum/GCB/Data Centers/dc_map_project/data/raw/datacenter_map_scraped_brasil.csv'

# %% [markdown]
# ## 2. Defining the unscrambling functions

# %%
def parse_field_value(value):
    """
    Parse a string in the format "{number} {category}" into a tuple (number, category).
    
    Args:
        value (str): The string to parse, e.g., "10 Servers" or "5.5 MW".
    
    Returns:
        tuple: A tuple containing (number, category). If the value is NaN or doesn't match the format,
               returns (None, None).
    """
    if pd.isna(value):
        return None, None
    
    # Remove leading/trailing whitespace
    value = value.strip()
    
    # Use regex to extract the number and category
    match = re.match(r'^\s*([\d.]+)\s+(.+)$', value)
    if match:
        number_str, category = match.groups()
        # Convert the number to float or int based on its format
        try:
            number = float(number_str) if '.' in number_str else int(number_str)
        except ValueError:
            number = number_str  # Fallback to string if conversion fails
        return number, category.strip()
    return None, None

def extract_fields_from_row(row):
    """
    Extract structured data from field columns in a row and return a Series of key-value pairs.
    
    Args:
        row (pd.Series): A row from the DataFrame.
    
    Returns:
        pd.Series: A Series where keys are categories and values are numbers.
    """
    extracted_fields = {}
    for col in field_columns:
        value = row[col]
        number, category = parse_field_value(value)
        if category is not None:
            # Keep the first occurrence of each category
            if category not in extracted_fields:
                extracted_fields[category] = number
    return pd.Series(extracted_fields)

# %% [markdown]
# ## 2. Applying the unscrambling functions

# %%
# Identify columns that start with 'field' (these contain structured data)
field_columns = [col for col in raw_datacenters.columns if col.startswith('field')]

# Apply the extraction function to each row
extracted_fields = raw_datacenters.apply(extract_fields_from_row, axis=1)

# Merge the extracted fields back into the original DataFrame
clean_datacenters = pd.concat(
    [raw_datacenters.drop(columns=field_columns), extracted_fields],
    axis=1
)

# %% [markdown]
# ## 3. Collapsing MW columns into a single one + adjusting column names

# %%
# First, convert both columns to numeric, coercing any non‐numeric values to NaN.
clean_datacenters["MW total power"] = pd.to_numeric(clean_datacenters["MW total power"], errors="coerce")
clean_datacenters["MW MW total power"] = pd.to_numeric(clean_datacenters["MW MW total power"], errors="coerce")

# Use combine_first to fill NaN values in "MW total power" with those from "MW MW total power"
clean_datacenters["MW total power"] = clean_datacenters["MW total power"].combine_first(clean_datacenters["MW MW total power"])

# Optionally, drop the duplicate column
clean_datacenters.drop(columns=["MW MW total power"], inplace=True)

# Dropping colocation products column, which contains terrible data
clean_datacenters.drop(columns=["colocation products"], inplace=True)

# Standardize column names by replacing spaces with underscores
clean_datacenters.columns = [colname.replace(' ', '_') for colname in clean_datacenters.columns]

# %%
sample = clean_datacenters.head()

# %%
def extract_address_components(address):
    """
    Given an address string in a format like:
      "street number street name, municipality, state [ZIP], USA"
    this function removes the trailing USA (or United States) part and returns a Series with:
      - number: The street number.
      - street: The remainder of the street address.
      - municipality: The municipality (city) name.
      - state: The state (with any ZIP code digits removed).
    If extraction fails, returns NaN for each component.
    """
    # Split the address by commas and trim whitespace
    parts = [part.strip() for part in address.split(',')]
    
    # Remove any trailing parts that are "USA" or "United States" (case-insensitive)
    while parts and parts[-1].upper() in ["USA", "UNITED STATES"]:
        parts.pop()
    
    # Expect at least three parts now: [street, municipality, state]
    # Extract the street portion (first part) and split it into number and street name.
    if parts and len(parts[0]) > 0:
        m = re.match(r'^(\d+)\s+(.*)$', parts[0])
        if m:
            number = m.group(1)
            street = m.group(2)
        else:
            # If the pattern doesn't match, return the whole thing as street.
            number, street = np.nan, parts[0]
    else:
        number, street = np.nan, np.nan

    # Municipality: if available, assume it's the next part.
    municipality = parts[1] if len(parts) >= 2 else np.nan

    # State: if available, assume it's the third part.
    # Also, remove any digits (e.g. ZIP codes) from it.
    state_candidate = parts[2] if len(parts) >= 3 else np.nan
    if isinstance(state_candidate, str):
        state = re.sub(r'\d+', '', state_candidate).strip()
    else:
        state = np.nan

    return pd.Series([number, street, municipality, state], index=['number', 'street', 'municipality', 'state'])

# Example usage: (assuming your cleaned DataFrame is named clean_datacenters)
clean_datacenters[['number', 'street', 'municipality', 'state']] = clean_datacenters['address'].apply(extract_address_components)

# %%
# Initialize the Nominatim geolocator with a longer timeout.
geolocator = Nominatim(user_agent="datacenter_geocoder", timeout=20)

def geocode_row(row):
    """
    Construct an address query from available components and return
    a (latitude, longitude) tuple by querying Nominatim.
    
    The row is assumed to have the following columns (possibly with NaN):
        - number: the street number (e.g., '101')
        - street: the street name (e.g., 'Herbert Drive')
        - municipality: the city (e.g., 'Boydton')
        - state: the state code or name (e.g., 'VA')
    
    This function builds a query string using the available pieces and
    appends 'USA' at the end.
    
    If the geocoding is successful, returns (latitude, longitude).
    Otherwise, returns (np.nan, np.nan).
    """
    components = []
    
    # If both number and street are available, combine them; otherwise, use what is available.
    if pd.notnull(row['number']) and pd.notnull(row['street']):
        components.append(f"{row['number']} {row['street']}")
    elif pd.notnull(row['street']):
        components.append(row['street'])
    
    # Add municipality if available.
    if pd.notnull(row['municipality']):
        components.append(row['municipality'])
    
    # Add state if available.
    if pd.notnull(row['state']):
        components.append(row['state'])
    
    # Append the country (helps Nominatim narrow down the query)
    components.append("USA")
    
    # Build the query address string.
    query_address = ", ".join(components)
    
    try:
        location = geolocator.geocode(query_address)
        # Pause briefly to respect Nominatim's rate limits.
        time.sleep(1)
        if location:
            return (location.latitude, location.longitude)
        else:
            # If no location found, return NaNs.
            return (np.nan, np.nan)
    except Exception as e:
        print(f"Error geocoding '{query_address}':", e)
        return (np.nan, np.nan)

# %%
# Now apply the geocoding function row by row and expand the returned tuple into new columns:
clean_datacenters[['latitude', 'longitude']] = clean_datacenters.apply(geocode_row, axis=1, result_type='expand')
# Out:
# Error geocoding '2000 East Lamar Boulevard, Arlington, TX, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2000+East+Lamar+Boulevard%2C+Arlington%2C+TX%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169df0850>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '624 South Grand Avenue, Los Angeles, CA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=624+South+Grand+Avenue%2C+Los+Angeles%2C+CA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7bfd0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '21715 Filigree Court, Ashburn, VA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=21715+Filigree+Court%2C+Ashburn%2C+VA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7bb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '5959 Corporate Drive, Houston, TX, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=5959+Corporate+Drive%2C+Houston%2C+TX%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7b130>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '12270 World Trade Drive, San Diego, CA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=12270+World+Trade+Drive%2C+San+Diego%2C+CA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e64910>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '2560 Beech Rd NW, Johnstown, Ohio, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2560+Beech+Rd+NW%2C+Johnstown%2C+Ohio%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x16961f1f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '8354 Northfield Blvd, Denver, CO, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=8354+Northfield+Blvd%2C+Denver%2C+CO%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e64f40>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '20632 Sycolin Rd, Leesburg, Loudoun, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=20632+Sycolin+Rd%2C+Leesburg%2C+Loudoun%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e64940>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '5121 Hayden Run Rd, Hilliard, Ohio, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=5121+Hayden+Run+Rd%2C+Hilliard%2C+Ohio%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7b400>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '12100 Sunrise Valley Drive, Reston, VA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=12100+Sunrise+Valley+Drive%2C+Reston%2C+VA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7b580>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '305 Satellite Boulevard, Suwanee, GA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=305+Satellite+Boulevard%2C+Suwanee%2C+GA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7b700>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '1 Summer Street, Boston, MA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=1+Summer+Street%2C+Boston%2C+MA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e65b80>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '4442 Newcastle Rd, Oklahoma City, Oklahoma, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=4442+Newcastle+Rd%2C+Oklahoma+City%2C+Oklahoma%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e65af0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '2570 Beech Rd NW, Johnstown, Ohio, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2570+Beech+Rd+NW%2C+Johnstown%2C+Ohio%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e654c0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '1299 Farnam Street, Omaha, NE, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=1299+Farnam+Street%2C+Omaha%2C+NE%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169df0880>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '5125 Hayden Run Rd, Hilliard, Ohio, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=5125+Hayden+Run+Rd%2C+Hilliard%2C+Ohio%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7beb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '555 California Street suite 4925, San Francisco, CA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q
USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=365+Main+Street%2C+San+Francisco%2C+CA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e686d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '2301 W 120th St, Hawthorne, California, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2301+W+120th+St%2C+Hawthorne%2C+California%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169dd4a00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '421 Fayetteville Street, Raleigh, NC, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=421+Fayetteville+Street%2C+Raleigh%2C+NC%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e650a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding 'Richard R. Lozano, Criminal Defense Lawyer St. Louis Missouri, S Bemiston Ave #, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Richard+R.+Lozano%2C+Criminal+Defense+Lawyer+St.+Louis+Missouri%2C+S+Bemiston+Ave+%23%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e65e50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '6645 Crosby Court, Dublin, OH, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=6645+Crosby+Court%2C+Dublin%2C+OH%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e64640>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '100 Technical Drive, New Kensington, PA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=100+Technical+Drive%2C+New+Kensington%2C+PA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7b550>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '2720 Zanker Road, San Jose, CA, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2720+Zanker+Road%2C+San+Jose%2C+CA%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7b700>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '1010 N 96th St ste 100, Omaha, NE, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=1010+N+96th+St+ste+100%2C+Omaha%2C+NE%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7bbb0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error geocoding '6645 Crosby Court, Dublin, Ohio, USA': HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=6645+Crosby+Court%2C+Dublin%2C+Ohio%2C+USA&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169e7b6a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
successfull1 = clean_datacenters[~clean_datacenters.latitude.isna()]

# %%
successfull_path = Path.cwd().parent / 'data' / 'processed' / 'successful1.csv'
successfull1.to_csv(successfull_path)

# %%
fail = clean_datacenters[clean_datacenters.latitude.isna()]

# %%
fail
# Out:
#                                                     url  \
# 0     https://datacenters.com/microsoft-azure-east-u...
# 5     https://datacenters.com/microsoft-azure-west-u...
# 8     https://datacenters.com/amazon-aws-pdx4-boardm...
# 14    https://datacenters.com/switch-switch-core-campus
# 15    https://datacenters.com/switch-switch-citadel-...
# ...                                                 ...
# 2054   https://datacenters.com/amazon-aws-crosby-campus
# 2055  https://datacenters.com/tecfusions-new-kensing...
# 2056       https://datacenters.com/navisite-santa-clara
# 2057  https://datacenters.com/opti9-technologies-neb...
# 2058  https://datacenters.com/amazon-aws-6645-crosby...
#
#                                                    name  \
# 0                     Microsoft Azure: East US-Virginia
# 5                 Microsoft Azure: West US 2-Washington
# 8                         Amazon AWS: PDX4 Boardman, OR
# 14    Switch Data Centers: Switch Data Centers: CORE...
# 15    Switch Data Centers: Switch Data Centers: CITA...
# ...                                                 ...
# 2054                          Amazon AWS: Crosby Campus
# 2055         TECfusions: New Kensington, PA Data Center
# 2056                  NaviSite: Santa Clara Data Center
# 2057           Opti9 Technologies: Nebraska Data Center
# 2058                      Amazon AWS: 6645 Crosby Court
#
#                                                 address  \
# 0                   101 Herbert Drive, Boydton, VA, USA
# 5             1515 Port Industrial Way, Quincy, WA, USA
# 8            79539 Rippee Road, Boardman, OR 97818, USA
# 14    Switch LAS VEGAS - The Core Campus, 7135 South...
# 15    Switch TAHOE RENO - The Citadel Campus, Superl...
# ...                                                 ...
# 2054                 6645 Crosby Court, Dublin, OH, USA
# 2055       100 Technical Drive, New Kensington, PA, USA
# 2056                2720 Zanker Road, San Jose, CA, USA
# 2057       1010 N 96th St ste 100, Omaha, NE 68114, USA
# 2058         6645 Crosby Court, Dublin, Ohio 43016, USA
#
#                                       provider  MW_total_power  \
# 0                              Microsoft Azure             NaN
# 5                              Microsoft Azure             NaN
# 8                                   Amazon AWS             NaN
# 14    Switch Data Centers: Switch Data Centers             NaN
# 15    Switch Data Centers: Switch Data Centers             NaN
# ...                                        ...             ...
# 2054                                Amazon AWS             NaN
# 2055                                TECfusions           200.0
# 2056                                  NaviSite             1.2
# 2057                        Opti9 Technologies             NaN
# 2058                                Amazon AWS             NaN
#
#       miles_to_nearest_airport  sqft_colocation_space  sqft_total_space  \
# 0                       175.23                    NaN         1100000.0
# 5                       114.34                    NaN          800000.0
# 8                       167.77                    NaN               NaN
# 14                        3.73                    NaN          471248.0
# 15                        3.73                    NaN               NaN
# ...                        ...                    ...               ...
# 2054                      2.76                    NaN               NaN
# 2055                      5.51                    NaN               NaN
# 2056                      1.90                    NaN               NaN
# 2057                      2.71                    NaN               NaN
# 2058                      2.76                    NaN               NaN
#
#      number                                  street  \
# 0       101                           Herbert Drive
# 5      1515                     Port Industrial Way
# 8     79539                             Rippee Road
# 14      NaN      Switch LAS VEGAS - The Core Campus
# 15      NaN  Switch TAHOE RENO - The Citadel Campus
# ...     ...                                     ...
# 2054   6645                            Crosby Court
# 2055    100                         Technical Drive
# 2056   2720                             Zanker Road
# 2057   1010                       N 96th St ste 100
# 2058   6645                            Crosby Court
#
#                       municipality      state  latitude  longitude
# 0                          Boydton         VA       NaN        NaN
# 5                           Quincy         WA       NaN        NaN
# 8                         Boardman         OR       NaN        NaN
# 14    7135 South Decatur Boulevard  Las Vegas       NaN        NaN
# 15                Superloop Circle     Sparks       NaN        NaN
# ...                            ...        ...       ...        ...
# 2054                        Dublin         OH       NaN        NaN
# 2055                New Kensington         PA       NaN        NaN
# 2056                      San Jose         CA       NaN        NaN
# 2057                         Omaha         NE       NaN        NaN
# 2058                        Dublin       Ohio       NaN        NaN
#
# [454 rows x 14 columns]

# %% [markdown]
# # Cell Tower data wrangling

# %%
# importing the cell tower data
towers_path = Path.cwd().parent / 'data' / 'raw' / 'cell_towers.csv'
towers = pd.read_csv(towers_path)

# %%
# keeping only USA towers
towers = towers[towers.mcc == 310]

# keeping only relevant columns
towers = towers[['cell', 'radio', 'lon', 'lat', 'range', 'created', 'updated']]

# converting timestamps to ISO format
towers['created'] = pd.to_datetime(towers['created'], unit='s').dt.strftime('%Y-%m-%d')
towers['updated'] = pd.to_datetime(towers['updated'], unit='s').dt.strftime('%Y-%m-%d')

# %%
# exporting towers dataframe to csv
towers_processed_path = Path.cwd().parent / 'data' / 'processed' / 'cell_towers_processed.csv'
towers.to_csv(towers_processed_path)
